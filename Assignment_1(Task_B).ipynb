# %% [markdown]
# Name : Ghotra Jaspreet Kaur
#
# ID : 202318058

# %%
import requests

url = "https://local-business-data.p.rapidapi.com/search"

querystring = {"query":"Hotels in San Francisco, USA","limit":"20","lat":"37.359428","lng":"-121.925337","zoom":"13","language":"en","region":"us"}

headers = {
"X-RapidAPI-Key": "ac3eab162dmsh29fde4d8d6b8770p13b94djsn68a32c5ac176",
"X-RapidAPI-Host": "local-business-data.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'OK', 'request_id': '4955f9c6-8970-49a1-86c8-d0c388a9fe50', 'parameters': {'query': 'Hotels in San Francisco, USA', 'language': 'en', 'region': 'us', 'lat': 37.359428, 'lng': -121.925337, 'zoom': 13, 'limit': 20, 'offset': 0}, 'data': [{'business_id': '0x8085808636673e71:0xebc2cf7c5bf2d655', 'google_id': '0x8085808636673e71:0xebc2cf7c5bf2d655', 'place_id': 'ChIJcT5nNoaAhYARVdbyW3zPwus', 'google_mid': '/m/03c9s02', 'phone_number': '+14158961600', 'name': 'San Francisco Marriott Marquis', 'latitude': 37.7853366, 'longitude': -122.40440679999999, 'full_address': 'San Francisco Marriott Marquis, 780 Mission St, San Francisco, CA 94103', 'review_count': 9259, 'rating': 4.4, 'timezone': 'America/Los_Angeles', 'working_hours': None, 'website': 'https://www.marriott.com/en-us/hotels/sfodt-san-francisco-marriott-marquis/overview/?scid=f2ae0541-1279-4f24-b197-a979c79310b0', 'verified': True, 'place_link': 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x8085808636673e71:
# ...

# %%
data = response.json()

# %%
data
# Out:
# {'status': 'OK',
#  'request_id': '4955f9c6-8970-49a1-86c8-d0c388a9fe50',
#  'parameters': {'query': 'Hotels in San Francisco, USA',
#   'language': 'en',
#   'region': 'us',
#   'lat': 37.359428,
#   'lng': -121.925337,
#   'zoom': 13,
#   'limit': 20,
#   'offset': 0},
#  'data': [{'business_id': '0x8085808636673e71:0xebc2cf7c5bf2d655',
#    'google_id': '0x8085808636673e71:0xebc2cf7c5bf2d655',
#    'place_id': 'ChIJcT5nNoaAhYARVdbyW3zPwus',
#    'google_mid': '/m/03c9s02',
#    'phone_number': '+14158961600',
#    'name': 'San Francisco Marriott Marquis',
#    'latitude': 37.7853366,
#    'longitude': -122.40440679999999,
#    'full_address': 'San Francisco Marriott Marquis, 780 Mission St, San Francisco, CA 94103',
#    'review_count': 9259,
#    'rating': 4.4,
#    'timezone': 'America/Los_Angeles',
#    'working_hours': None,
#    'website': 'https://www.marriott.com/en-us/hotels/sfodt-san-francisco-marriott-marquis/overview/?scid=f2ae0541-1279-4f24-b197-a979c79310b0',
# ...

# %%
hotel_names = [entry['name'] for entry in data['data']]
print(hotel_names)
# Out:
# ['San Francisco Marriott Marquis', 'Holiday Inn San Francisco-Golden Gateway, an IHG Hotel', 'Hilton San Francisco Financial District', 'The Marker San Francisco', 'Hilton San Francisco Union Square', 'Hyatt Regency San Francisco', 'Hotel Zephyr San Francisco', 'Hotel Griffon', 'Hotel Riu Plaza Fisherman´s Wharf', 'Queen Anne Hotel', 'Hampton Inn San Francisco Downtown/Convention Center', 'Holiday Inn Express & Suites San Francisco Fishermans Wharf, an IHG Hotel', 'Harbor Court', 'San Francisco Marriott Union Square', '1906 Mission', 'Warfield Hotel', 'Fairmont San Francisco', 'San Remo Hotel', "HI San Francisco Fisherman's Wharf Hostel", "San Francisco Marriott Fisherman's Wharf"]

# %%
phone_numbers = [entry['phone_number'] for entry in data['data']]
print(phone_numbers)
# Out:
# ['+14158961600', '+14154414000', '+14154336600', '+18884461150', '+14157711400', '+14157881234', '+14156176565', '+14154952100', '+14153625500', '+14154412828', '+14155463110', '+14154094600', '+14158821300', '+14153988900', '+14157839914', '+14154005153', '+14157725000', '+14157768688', '+14157717277', '+14157757555']

# %%
full_address = [entry['full_address'] for entry in data['data']]
print(full_address)
# Out:
# ['San Francisco Marriott Marquis, 780 Mission St, San Francisco, CA 94103', 'Holiday Inn San Francisco-Golden Gateway, an IHG Hotel, 1500 Van Ness Ave, San Francisco, CA 94109', 'Hilton San Francisco Financial District, 750 Kearny St, San Francisco, CA 94108', 'The Marker San Francisco, 501 Geary St, San Francisco, CA 94102', "Hilton San Francisco Union Square, 333 O'Farrell St, San Francisco, CA 94102", 'Hyatt Regency San Francisco, 5 Embarcadero Ctr, San Francisco, CA 94111', 'Hotel Zephyr San Francisco, 250 Beach St, San Francisco, CA 94133', 'Hotel Griffon, 155 Steuart St, San Francisco, CA 94105', 'Hotel Riu Plaza Fisherman´s Wharf, 2500 Mason St, San Francisco, CA 94133', 'Queen Anne Hotel, 1590 Sutter St, San Francisco, CA 94109', 'Hampton Inn San Francisco Downtown/Convention Center, 942 Mission St, San Francisco, CA 94103', 'Holiday Inn Express & Suites San Francisco Fishermans Wharf, an IHG Hotel, 550 North Point St, San Francisco, CA 94133', 'Harbor Court, 165 Steuart St, 
# ...

# %%
review_count = [entry['review_count'] for entry in data['data']]
print(review_count)
# Out:
# [9259, 3286, 4959, 1389, 10576, 6569, 3418, 687, 2025, 602, 1282, 1714, 840, 1890, 159, 692, 6316, 817, 1057, 1678]

# %%
rating = [entry['rating'] for entry in data['data']]
print(rating)
# Out:
# [4.4, 4, 3.9, 4.1, 4.2, 4.4, 4.2, 4.2, 4, 4.4, 3.9, 4.2, 4.2, 4.3, 4.3, 3, 4.5, 4.4, 4.4, 4.2]

# %%
website = [entry['website'] for entry in data['data']]
print(website)
# Out:
# ['https://www.marriott.com/en-us/hotels/sfodt-san-francisco-marriott-marquis/overview/?scid=f2ae0541-1279-4f24-b197-a979c79310b0', 'https://www.ihg.com/holidayinn/hotels/us/en/san-francisco/sfogg/hoteldetail?cm_mmc=GoogleMaps-_-HI-_-US-_-SFOGG', 'https://www.hilton.com/en/hotels/sfofdhf-hilton-san-francisco-financial-district/?SEO_id=GMB-AMER-HH-SFOFDHF&y_source=1_MTIyMDk1Ni03MTUtbG9jYXRpb24ud2Vic2l0ZQ%3D%3D', 'https://www.themarkersf.com', 'https://www.hilton.com/en/hotels/sfofhhh-hilton-san-francisco-union-square/?SEO_id=GMB-AMER-HH-SFOFHHH&y_source=1_NzIxNzU4LTcxNS1sb2NhdGlvbi53ZWJzaXRl', 'https://www.hyatt.com/en-US/hotel/california/hyatt-regency-san-francisco/sfors/?src=corp_lclb_gmb_seo_sfors', 'https://www.hotelzephyrsf.com', 'https://www.hotelgriffon.com', 'https://www.riu.com/en/hotel/usa/san-francisco/hotel-riu-plaza-fishermans-wharf', 'https://www.queenanne.com', 'https://www.hilton.com/en/hotels/sfocchx-hampton-san-francisco-downtown-convention-center/?SEO_id=GMB-AMER-HX-
# ...

# %%
place_link = [entry['place_link'] for entry in data['data']]
print(place_link)
# Out:
# ['https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x8085808636673e71:0xebc2cf7c5bf2d655', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x808580953b304983:0xf80b9c8c620e6b91', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x8085808b287f3b3b:0xa49802f84f7ddb35', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x8085808e30d1732b:0x3a2a4b3433526e60', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x8085808fa0472279:0x49345c4565f1667a', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x808580614d1f605f:0x84660c500c409d2b', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x808580e35111d5f7:0x34b0de1453599ed0', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x80858065a5622f51:0x8b5b90175a272864', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x80858177a1112eeb:0x174b910df3197d5b', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x808580bfa92778f1:0xc42c6bf0e643c8a9', 'https:
# ...

# %%
timezone = [entry['timezone'] for entry in data['data']]
print(timezone)
# Out:
# ['America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles', 'America/Los_Angeles']

# %%
cid = [entry['cid'] for entry in data['data']]
print(cid)
# Out:
# ['16988368877420467797', '17873551672904412049', '11860232884188994357', '4191245090793090656', '5274942516690511482', '9540326398573452587', '3796778664752422608', '10041778224123816036', '1678594775224778075', '14135792012808669353', '15596476296395846267', '12536054940402979311', '1229582272471895272', '197650393429966469', '2611178186857308571', '14027203898460930783', '932337608444387060', '846374809856820942', '10885908252466816551', '1608295128851941453']

# %%
reviews_link = [entry['reviews_link'] for entry in data['data']]
print(reviews_link)
# Out:
# ['https://search.google.com/local/reviews?placeid=ChIJcT5nNoaAhYARVdbyW3zPwus&q=Hotels+in+San+Francisco,+USA&authuser=0&hl=en&gl=US', 'https://search.google.com/local/reviews?placeid=ChIJg0kwO5WAhYARkWsOYoycC_g&q=Hotels+in+San+Francisco,+USA&authuser=0&hl=en&gl=US', 'https://search.google.com/local/reviews?placeid=ChIJOzt_KIuAhYARNdt9T_gCmKQ&q=Hotels+in+San+Francisco,+USA&authuser=0&hl=en&gl=US', 'https://search.google.com/local/reviews?placeid=ChIJK3PRMI6AhYARYG5SMzRLKjo&q=Hotels+in+San+Francisco,+USA&authuser=0&hl=en&gl=US', 'https://search.google.com/local/reviews?placeid=ChIJeSJHoI-AhYARembxZUVcNEk&q=Hotels+in+San+Francisco,+USA&authuser=0&hl=en&gl=US', 'https://search.google.com/local/reviews?placeid=ChIJX2AfTWGAhYARK51ADFAMZoQ&q=Hotels+in+San+Francisco,+USA&authuser=0&hl=en&gl=US', 'https://search.google.com/local/reviews?placeid=ChIJ99URUeOAhYAR0J5ZUxTesDQ&q=Hotels+in+San+Francisco,+USA&authuser=0&hl=en&gl=US', 'https://search.google.com/local/reviews?placeid=ChIJUS9ipWWAhYARZ
# ...

# %%
type_1 = [entry['type'] for entry in data['data']]
print(type_1)
# Out:
# ['Hotel', 'Hotel', 'Hotel', 'Hotel', 'Hotel', 'Hotel', 'Hotel', 'Hotel', 'Hotel', 'Hotel', 'Hotel', 'Hotel', 'Hotel', 'Hotel', 'Extended stay hotel', 'Hotel', 'Hotel', 'Hotel', 'Hostel', 'Hotel']

# %%
place_link = [entry['place_link'] for entry in data['data']]
print(place_link)
# Out:
# ['https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x8085808636673e71:0xebc2cf7c5bf2d655', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x808580953b304983:0xf80b9c8c620e6b91', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x8085808b287f3b3b:0xa49802f84f7ddb35', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x8085808e30d1732b:0x3a2a4b3433526e60', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x8085808fa0472279:0x49345c4565f1667a', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x808580614d1f605f:0x84660c500c409d2b', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x808580e35111d5f7:0x34b0de1453599ed0', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x80858065a5622f51:0x8b5b90175a272864', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x80858177a1112eeb:0x174b910df3197d5b', 'https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x808580bfa92778f1:0xc42c6bf0e643c8a9', 'https:
# ...

# %%
import pandas as pd
df = pd.DataFrame({
    'hotel_names': hotel_names,
    'phone_numbers': phone_numbers,
    'full_address': full_address,
    'review_count': review_count,
    'rating': rating,
    'timezone':timezone,
    'website':website,
    'place_link':place_link,
    'cid':cid,
    'reviews_link':reviews_link,
    'type_1':type})

# %%
df
# Out:
#                                           hotel_names phone_numbers  \
# 0                      San Francisco Marriott Marquis  +14158961600
# 1   Holiday Inn San Francisco-Golden Gateway, an I...  +14154414000
# 2             Hilton San Francisco Financial District  +14154336600
# 3                            The Marker San Francisco  +18884461150
# 4                   Hilton San Francisco Union Square  +14157711400
# 5                         Hyatt Regency San Francisco  +14157881234
# 6                          Hotel Zephyr San Francisco  +14156176565
# 7                                       Hotel Griffon  +14154952100
# 8                   Hotel Riu Plaza Fisherman´s Wharf  +14153625500
# 9                                    Queen Anne Hotel  +14154412828
# 10  Hampton Inn San Francisco Downtown/Convention ...  +14155463110
# 11  Holiday Inn Express & Suites San Francisco Fis...  +14154094600
# 12                                       Harbor Court  +14158821300
# ...
